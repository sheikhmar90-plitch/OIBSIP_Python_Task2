# %% [markdown]
# # Task:1
# # *BMI* Calculator

# %%
weight_kg = float(input("Enter your weight in kg: "))
height_m = float(input("Enter your height in meters: "))

if weight_kg <= 0 or height_m <= 0:
    print("Please enter realistic positive values for weight and height.")
else:
    BMI = weight_kg / height_m**2
    print(f"Your BMI is: {BMI:.2f}")

    if BMI < 18.5:
        print("You are underweight")
    elif 18.5 <= BMI < 25:
        print("You have normal weight")
    elif 25 <= BMI < 30:
        print("You are overweight")
    else:
        print("You are obese")
# Out:
# Enter your weight in kg: 68
# Enter your height in meters: 1.8
# Your BMI is: 20.99
# You have normal weight

# %% [markdown]
# # Summary
# This program takes the user's weight and height, calculates their BMI, and displays their BMI category (underweight, normal, overweight, or obese).
